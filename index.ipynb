# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in pandas.

# %%
# Replace None with appropriate code

# Import pandas using the standard alias
import pandas as pd

# Load 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv('WorldCupMatches.csv')

# %% [markdown]
# ## Common Methods and Attributes

# %% [markdown]
# Use the correct method to display the **first 7 rows** of the dataset.

# %%
# Your code here
df[:8]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 7  1930  17 Jul 1930 - 14:45   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
# 7            USA                3                0       Paraguay
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
# 7                    18306.0                     2                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
# 7         MACIAS Jose (ARG)   APHESTEGUY Martin (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
# 7         TEJADA Anibal (URU)      201     1097                USA
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL
# 7                PAR

# %% [markdown]
# Display the **last 3 rows** of the dataset.

# %%
# Your code here
df[-8:]
# Out:
#      Year              Datetime                     Stage  \
# 844  2014  04 Jul 2014 - 13:00             Quarter-finals
# 845  2014  04 Jul 2014 - 17:00             Quarter-finals
# 846  2014  05 Jul 2014 - 13:00             Quarter-finals
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 844  Estadio do Maracana  Rio De Janeiro          France                0
# 845     Estadio Castelao       Fortaleza          Brazil                2
# 846     Estadio Nacional        Brasilia       Argentina                1
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 844                1        Germany
# 845                1       Colombia
# 846                0        Belgium
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 844     74240.0                     0                     1
# 845     60342.0                     1                     0
# 846     68551.0                     1                     0
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                            Referee                     Assistant 1  \
# 844            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 845  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 846           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 847          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 848          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
# 849             C�neyt �AKIR (TUR)            DURAN Bahattin (TUR)
# 850          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 851           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
#
#                   Assistant 2  RoundID    MatchID Home Team Initials  \
# 844  BELATTI Juan Pablo (ARG)   255953  300186485                FRA
# 845          YUSTE Juan (ESP)   255953  300186461                BRA
# 846      Andrea STEFANI (ITA)   255953  300186504                ARG
# 847  KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848     QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849         ONGUN Tarik (TUR)   255955  300186490                NED
# 850   ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851      Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 844                GER
# 845                COL
# 846                BEL
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# Your code here
df.info
# Out:
# <bound method DataFrame.info of      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# 2         Parque Central      Montevideo      Yugoslavia                2
# 3                Pocitos      Montevideo         Romania                3
# 4         Parque Central      Montevideo       Argentina                1
# ..                   ...              ...            ...              ...
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 0                  1         Mexico
# 1                  0        Belgium
# 2                  1         Brazil
# 3                  1           Peru
# 4                  0         France
# ..               ...            ...                                    ...
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0        4444.0                     3                     0
# 1       18346.0                     2                     0
# 2       24059.0                     2                     0
# 3        2549.0                     1                     0
# 4       23409.0                     0                     0
# ..          ...                   ...                   ...
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                     Referee                  Assistant 1  \
# 0    LOMBARDI Domingo (URU)        CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)     MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)      VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)          LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)         SAUCEDO Ulises (BOL)
# ..                      ...                          ...
# 847   Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 848   RODRIGUEZ Marco (MEX)      TORRENTERA Marvin (MEX)
# 849      C�neyt �AKIR (TUR)         DURAN Bahattin (TUR)
# 850   HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 851    Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
#
#                     Assistant 2  RoundID    MatchID Home Team Initials  \
# 0           REGO Gilberto (BRA)      201       1096                FRA
# 1         WARNKEN Alberto (CHI)      201       1090                USA
# 2           BALWAY Thomas (FRA)      201       1093                YUG
# 3      MATEUCCI Francisco (URU)      201       1098                ROU
# 4    RADULESCU Constantin (ROU)      201       1085                ARG
# ..                          ...      ...        ...                ...
# 847    KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848       QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849           ONGUN Tarik (TUR)   255955  300186490                NED
# 850     ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851        Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 0                  MEX
# 1                  BEL
# 2                  BRA
# 3                  PER
# 4                  FRA
# ..                 ...
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG
#
# [852 rows x 20 columns]>

# %% [markdown]
# Obtain a tuple representing the **number of rows and number of columns**.

# %%
# Your code here
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the **column names**.

# %%
# Your code here
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting DataFrame Information

# %% [markdown]
# When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. **select rows 3 through 5 inclusive**).

# %%
# Your code here
df[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, display the info from **game 5-9** (inclusive), but **only the `"Home Team Name"` and the `"Away Team Name"` columns**.

# %%
# Your code here
df.loc[5:10,('Home Team Name','Away Team Name')]
# Out:
#    Home Team Name Away Team Name
# 5           Chile         Mexico
# 6      Yugoslavia        Bolivia
# 7             USA       Paraguay
# 8         Uruguay           Peru
# 9           Chile         France
# 10      Argentina         Mexico

# %% [markdown]
# Next, we'd like the information on all the games played in **Group 3** for the **1950** World Cup.

# %% [markdown]
# Hint: You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# Your code here
df[(df['Year']==1950) & (df['Stage']=='Group 3')]
# Out:
#       Year              Datetime    Stage           Stadium        City  \
# 56  1950.0  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950.0  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950.0  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden              3.0              2.0          Italy
# 61         Sweden              2.0              2.0       Paraguay
# 65          Italy              2.0              0.0       Paraguay
#
#    Win conditions  ...  Half-time Away Goals                Referee  \
# 56                 ...                   1.0        LUTZ Jean (SUI)
# 61                 ...                   1.0  MITCHELL Robert (SCO)
# 65                 ...                   0.0     ELLIS Arthur (ENG)
#
#                Assistant 1                Assistant 2 RoundID MatchID  \
# 56     BERANEK Alois (AUT)        TEJADA Carlos (MEX)   208.0  1219.0
# 61       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)   208.0  1228.0
# 65  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)   208.0  1218.0
#
#     Home Team Initials  Away Team Initials Total Goals Total Goals1
# 56                 SWE                 ITA         NaN          5.0
# 61                 SWE                 PAR         NaN          4.0
# 65                 ITA                 PAR         NaN          2.0
#
# [3 rows x 22 columns]

# %% [markdown]
# Let's repeat the command above, but this time display **only the attendance column** for the Group 3 games.

# %%
# Your code hereGroup 
df.loc[(df['Year']==1950) & (df['Stage']=='Group 3'), 'Attendance']
# Out:
# 56    36502.0
# 61     7903.0
# 65    25811.0
# Name: Attendance, dtype: float64

# %% [markdown]
# Throughout the entire history of the World Cup as recorded in this dataset, **how many home games were played by the Netherlands**?
#
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# Your code here
len(df[(df['Home Team Name']=='Netherlands') | (df['Away Team Name']=='Netherlands')])
# Out:
# 54

# %% [markdown]
# **How many games were played by the Netherlands in total**?

# %%
# Your code here
54

# %% [markdown]
# Next, let's try and figure out **how many games the USA played in the 2014 World Cup**.

# %%
# Your code here
len(df[((df['Home Team Name']=='USA') | (df['Away Team Name']=='USA')) & (df['Year']==2014)])
# Out:
# 5

# %% [markdown]
# Now, let's try to find out **how many countries participated in the 1986 World Cup**.

# %% [markdown]
# Hint 1: As a first step, create a new dataset that only contains games in that year.
#
# Hint 2: Make sure you don't end up with duplicate country names. Consider using `set()` or `.unique()`.

# %%
# Your code here
df1 = df[df['Year']==1986]
df1['Home Team Name'].unique()
df1['Away Team Name'].unique()
# Out:
# array(['Italy', 'France', 'Brazil', 'Hungary', 'Korea Republic', 'Poland',
#        'Northern Ireland', 'Mexico', 'England', 'Iraq', 'Denmark',
#        'Germany FR', 'Argentina', 'Soviet Union', 'Bulgaria', 'Canada',
#        'Algeria', 'Morocco', 'Spain', 'Paraguay', 'Portugal', 'Belgium',
#        'Uruguay', 'Scotland'], dtype=object)

# %% [markdown]
# ## Changing Values and Creating New Columns

# %% [markdown]
# In World Cup history, **how many matches had 5 goals or more in total**? Create a column `"Total Goals"` to answer this question.

# %%
# Your code here
df['Total Goals1'] = (df['Home Team Goals'])+(df['Away Team Goals'])
len(df[(df['Total Goals1']>=5)])
# Out:
# 147

# %% [markdown]
# Now **create a new column `"Half-time Goals"`** in `df` that includes both home and away values.

# %%
# Your code here
df['Half-Time Goals'] = (df['Half-time Home Goals']) + (df['Half-time Away Goals'])

# %%
# Run this cell without changes to see your new column
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Total Goals1', 'Half-Time Goals'],
#       dtype='object')

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Run this cell without changes

# Display all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']

#this code is breaking for some reason
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-26cea26795ae> in <module>
#       2
#       3 # Display all records containing the string 'Korea'
# ----> 4 df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
#       5
#       6 #this code is breaking for some reason
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     808                     return section
#     809                 # This is an elided recursive call to iloc/loc
# --> 810                 return getattr(section, self.name)[new_key]
#     811
#     812         raise IndexingError("not applicable")
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1087             self._validate_key(key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
# -> 1089         elif com.is_bool_indexer(key):
#    1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns 
koreanames = ['Korea DPR', 'Korea Republic']
koreainitials = ['KOR', 'PRK']


df.loc[df['Home Team Name'].isin(koreanames), 'Home Team Name'] = 'Korea'
df.loc[df['Away Team Name'].isin(koreanames), 'Away Team Name'] = 'Korea'
df.loc[df['Home Team Initials'].isin(koreainitials), 'Home Team Initials'] = 'NSK'
df.loc[df['Away Team Initials'].isin(koreainitials), 'Away Team Initials'] = 'NSK'

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
set(df['Home Team Initials'])
# Out:
# {'ALG',
#  'ANG',
#  'ARG',
#  'AUS',
#  'AUT',
#  'BEL',
#  'BIH',
#  'BOL',
#  'BRA',
#  'BUL',
#  'CAN',
#  'CHI',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COL',
#  'CRC',
#  'CRO',
#  'CUB',
#  'CZE',
#  'DEN',
#  'ECU',
#  'ENG',
#  'ESP',
#  'FRA',
#  'FRG',
#  'GDR',
#  'GER',
#  'GHA',
#  'GRE',
#  'HAI',
#  'HON',
#  'HUN',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ITA',
#  'JAM',
#  'JPN',
#  'KSA',
#  'MAR',
#  'MEX',
#  'NED',
#  'NGA',
#  'NIR',
#  'NOR',
#  'NSK',
#  'NZL',
#  'PAR',
#  'PER',
#  'POL',
#  'POR',
#  'ROU',
#  'RSA',
#  'RUS',
#  'SCG',
#  'SCO',
#  'SEN',
#  'SRB',
#  'SUI',
#  'SVK',
#  'SVN',
#  'SWE',
#  'TCH',
#  'TOG',
#  'TRI',
#  'TUN',
#  'TUR',
#  'UAE',
#  'UKR',
#  'URS',
#  'URU',
#  'USA',
#  'WAL',
#  'YUG',
#  'ZAI',
#  nan,
#  nan}

# %% [markdown]
# ## Summary
#
# In this lab, you practiced accessing data within Pandas!
